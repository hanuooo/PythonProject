# %%
import pandas as pd
from faker import Faker

# %%
fake=Faker('ko_KR') # 페이커 객체

# %%
# CSV 파일 : Comma Separate Value
# 엑셀에서 볼수 있는 텍스트 형식 파일
# 콤마를 구분자로 하여 데이터를 표현해주는 파일
# Out:
# '인천광역시 관악구 반포대4거리 지하3 (민재김장면)'

# %%
csvlist = [] # csv 파일로 저장할 리스트 데이터
columns01 = ['아이디', '이름', '주소', '전화번호', '이메일'] # 컬럼 이름
myencoding = 'UTF-8' # CP949 'UTF-8' 인코딩 문자열

# %%
for idx in range(10):
    onerow = [] # csv에 저장될 한건의 데이터
    onerow.append(fake.user_name())
    onerow.append(fake.name())
    onerow.append(fake.address())
    onerow.append(fake.phone_number())
    onerow.append(fake.email())

    csvlist.append(onerow) # 1줄 추가
# end for

# %%
print(csvlist)
# Out:
# [['minji32', '윤민지', '인천광역시 은평구 오금길 739 (동현안류동)', '054-682-8157', 'mo@example.org'], ['rbag', '정영순', '서울특별시 노원구 반포대07길 232-53 (옥순김황리)', '031-871-0995', 'iyujin@example.net'], ['yeongsungim', '이상현', '울산광역시 용산구 오금로 109-10 (중수송홍읍)', '043-836-9758', 'hyeonui@example.org'], ['jeongsugim', '윤예은', '울산광역시 중랑구 선릉가 128-10 (은영김김읍)', '064-727-1648', 'minseogim@example.net'], ['sunjagim', '최영철', '강원도 옥천군 삼성3가 997-65 (지현오이마을)', '052-291-6739', 'gimhyeonjun@example.com'], ['sugja48', '이은지', '전라북도 하남시 봉은사길 682 (은서이신면)', '052-879-6430', 'jihyeonjang@example.org'], ['dohyeoni', '전은경', '부산광역시 서구 백제고분608거리 222 (예진윤면)', '010-0842-4240', 'songyeongsug@example.org'], ['eungyeonggim', '류영철', '대구광역시 중랑구 백제고분거리 694-33', '041-592-7675', 'jeonghyigim@example.org'], ['iboram', '홍민석', '제주특별자치도 구리시 반포대로 448-13 (지은류동)', '043-104-3728', 'vgim@example.org'], ['ugim', '이정순', '세종특별자치시 성북구 잠실5길 914', '061-498-8172', 'nyun@example.org']]

# %%
myframe01 = pd.DataFrame(csvlist, columns=columns01)
print('데이터 프레임 내용 확인')
myframe01
# Out:
# 데이터 프레임 내용 확인
#            아이디   이름                                  주소          전화번호  \
# 0   jeongung93  김현숙        강원도 보령시 오금64가 지하783 (성호곽김마을)  032-466-6308
# 1     gimboram  손재호                인천광역시 종로구 선릉로 854-91  016-462-5450
# 2         qgim  강준서      세종특별자치시 동대문구 삼성37길 962 (영순김마을)  044-430-8041
# 3       ijimin  황정호                 광주광역시 영등포구 선릉2길 595  063-789-5243
# 4  hyeonjungim  이도현                  광주광역시 성동구 반포대가 235  062-623-2009
# 5     gimsubin  권성호                 충청북도 이천시 삼성042길 343  018-403-4402
# 6    ryuhyeonu  오영철             제주특별자치도 옥천군 가락86가 822-2  062-561-7295
# 7   yeonggil79  심서영                 전라남도 계룡시 양재천82로 593  055-058-1709
# 8  gimhyeonsug  박정호  인천광역시 영등포구 봉은사63거리 830-42 (미경장윤마을)  052-159-4561
# 9   seongminan  김옥자                 인천광역시 구로구 영동대7길 497  062-977-5542
#
#                         이메일
# 0       jihun71@example.net
# 1       eunseoi@example.net
# 2            ri@example.net
# 3            vi@example.net
# 4  coeyeonghwan@example.net
# 5     iseungmin@example.net
# 6       jinho01@example.org
# 7         ogang@example.org
# 8       ijiweon@example.com
# 9            si@example.net

# %%
dataIn = './../dataIn/' # 읽어 들일 파일이 저장되어 있는 폴더 ( 디렉토리 )
dataOut = './../dataOut/' # 결과 값을 저장할 폴더 ( 디렉토리 )

# %%
filename = 'result01.csv'
myframe01.to_csv(filename, encoding=myencoding, index=False , mode='w')

# %%
# 파일 읽어 오기
yourframe = pd.read_csv(filename, encoding=myencoding)
print(type(yourframe))
yourframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            아이디   이름                                  주소          전화번호  \
# 0   jeongung93  김현숙        강원도 보령시 오금64가 지하783 (성호곽김마을)  032-466-6308
# 1     gimboram  손재호                인천광역시 종로구 선릉로 854-91  016-462-5450
# 2         qgim  강준서      세종특별자치시 동대문구 삼성37길 962 (영순김마을)  044-430-8041
# 3       ijimin  황정호                 광주광역시 영등포구 선릉2길 595  063-789-5243
# 4  hyeonjungim  이도현                  광주광역시 성동구 반포대가 235  062-623-2009
# 5     gimsubin  권성호                 충청북도 이천시 삼성042길 343  018-403-4402
# 6    ryuhyeonu  오영철             제주특별자치도 옥천군 가락86가 822-2  062-561-7295
# 7   yeonggil79  심서영                 전라남도 계룡시 양재천82로 593  055-058-1709
# 8  gimhyeonsug  박정호  인천광역시 영등포구 봉은사63거리 830-42 (미경장윤마을)  052-159-4561
# 9   seongminan  김옥자                 인천광역시 구로구 영동대7길 497  062-977-5542
#
#                         이메일
# 0       jihun71@example.net
# 1       eunseoi@example.net
# 2            ri@example.net
# 3            vi@example.net
# 4  coeyeonghwan@example.net
# 5     iseungmin@example.net
# 6       jinho01@example.org
# 7         ogang@example.org
# 8       ijiweon@example.com
# 9            si@example.net

# %%
myencoding = 'CP949'

# %%
filename = dataIn + 'payment01.csv'
payment = pd.read_csv(filename, encoding=myencoding)
print('데이터 프레임 확인')
payment
# Out:
# 데이터 프레임 확인
#     사원명 출장지역  출장기간   부서  성별     교통비   식비
# 0   강미림   서울   3.0  영업부  남자  1000.0  500
# 1   장도윤   서울   NaN  총무부  남자  2000.0  300
# 2   김상민   부산   7.0  전산부  남자  3000.0  600
# 3   신승현   부산   5.0  영업부  여자     NaN  200
# 4  선우재민   서울   6.0  총무부  여자  4000.0  800

# %%
print('행 색인 정보 확인')
print(payment.index)
# Out:
# 행 색인 정보 확인
# RangeIndex(start=0, stop=5, step=1)

# %%
print('열 색인 정보 확인')
print(payment.columns)
# Out:
# 열 색인 정보 확인
# Index(['사원명', '출장지역', '출장기간', '부서', '성별', '교통비', '식비'], dtype='object')

# %%
business = payment['출장지역']
business
# Out:
# 0    서울
# 1    서울
# 2    부산
# 3    부산
# 4    서울
# Name: 출장지역, dtype: object

# %%
print('출장 지역 빈도수 확인')
business.value_counts()
# Out:
# 출장 지역 빈도수 확인
# 출장지역
# 서울    3
# 부산    2
# Name: count, dtype: int64

# %%
paytravel = payment['교통비']
type(paytravel)
# Out:
# pandas.core.series.Series

# %%
print(f'시리즈 요소 갯수 확인 : {paytravel.size}')
print(f'형상 확인 : {paytravel.shape}')
print(f'전체 요소 갯수 확인 : {len(paytravel)}')
print(f'카운트(결측치 제외) : {paytravel.count()}')
print(f'시리즈 타입 확인 : {paytravel.dtype}')
print(f'누락된 데이터가 있나요? : {paytravel.hasnans}')
print(f'모든 항목이 유일(unique)하나요? : {paytravel.is_unique}')
# Out:
# 시리즈 요소 갯수 확인 : 5
# 형상 확인 : (5,)
# 전체 요소 갯수 확인 : 5
# 카운트(결측치 제외) : 4
# 시리즈 타입 확인 : float64
# 누락된 데이터가 있나요? : True
# 모든 항목이 유일(unique)하나요? : True

# %%
business = payment['출장기간']
business
# Out:
# 0    3.0
# 1    NaN
# 2    7.0
# 3    5.0
# 4    6.0
# Name: 출장기간, dtype: float64

# %%
print(f'사분위수 : {business.quantile()}') # 기본값 q=0.5(50%에 해당하는 값)
print(f'최소값 : {business.min()}')
print(f'최대값 : {business.max()}')
print(f'평균 : {business.mean()}')
print(f'중앙값 : {business.median()}')
print(f'표준 편차 : {business.std()}')
print(f'총합 : {business.sum()}')
# Out:
# 사분위수 : 5.5
# 최소값 : 3.0
# 최대값 : 7.0
# 평균 : 5.25
# 중앙값 : 5.5
# 표준 편차 : 1.707825127659933
# 총합 : 21.0

# %%
payment
# Out:
#     사원명 출장지역  출장기간   부서  성별     교통비   식비
# 0   강미림   서울   3.0  영업부  남자  1000.0  500
# 1   장도윤   서울   NaN  총무부  남자  2000.0  300
# 2   김상민   부산   7.0  전산부  남자  3000.0  600
# 3   신승현   부산   5.0  영업부  여자     NaN  200
# 4  선우재민   서울   6.0  총무부  여자  4000.0  800

# %%
# '사원명' 컬럼을 행 색인으로 옮기기
payment = payment.set_index('사원명')
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500
# 장도윤    서울   NaN  총무부  남자  2000.0  300
# 김상민    부산   7.0  전산부  남자  3000.0  600
# 신승현    부산   5.0  영업부  여자     NaN  200
# 선우재민   서울   6.0  총무부  여자  4000.0  800

# %%
renamed_row = {'장도윤':'장태경', '선우재민':'밥값'}
renamed_col = {'출장지역':'다녀온곳', '식비':'밥값'}

# %%
payment = payment.rename(index=renamed_row, columns=renamed_col)
payment
# Out:
#      다녀온곳  출장기간   부서  성별     교통비   밥값
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500
# 장태경    서울   NaN  총무부  남자  2000.0  300
# 김상민    부산   7.0  전산부  남자  3000.0  600
# 신승현    부산   5.0  영업부  여자     NaN  200
# 선우은경   서울   6.0  총무부  여자  4000.0  800

# %%
filename = dataIn + 'payment01.csv'
# index_col='사원명' 옵션은 파일 읽어 들일 때에 바로 행 색인으로 옮기는 옵션
payment = pd.read_csv(filename, encoding=myencoding, index_col='사원명')
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500
# 장도윤    서울   NaN  총무부  남자  2000.0  300
# 김상민    부산   7.0  전산부  남자  3000.0  600
# 신승현    부산   5.0  영업부  여자     NaN  200
# 선우재민   서울   6.0  총무부  여자  4000.0  800

# %%
payment['차량 지원'] = '지원'
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비 차량 지원
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500    지원
# 장도윤    서울   NaN  총무부  남자  2000.0  300    지원
# 김상민    부산   7.0  전산부  남자  3000.0  600    지원
# 신승현    부산   5.0  영업부  여자     NaN  200    지원
# 선우재민   서울   6.0  총무부  여자  4000.0  800    지원

# %%
# 파생 컬럼
payment['최종 식비'] = payment['식비'] + 100
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비 차량 지원  최종 식비
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500    지원    600
# 장도윤    서울   NaN  총무부  남자  2000.0  300    지원    400
# 김상민    부산   7.0  전산부  남자  3000.0  600    지원    700
# 신승현    부산   5.0  영업부  여자     NaN  200    지원    300
# 선우재민   서울   6.0  총무부  여자  4000.0  800    지원    900

# %%
result = payment.drop('신승현', axis='index' )
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비 차량 지원  최종 식비
# 사원명
# 강미림    서울   3.0  영업부  남자  1000.0  500    지원    600
# 장도윤    서울   NaN  총무부  남자  2000.0  300    지원    400
# 김상민    부산   7.0  전산부  남자  3000.0  600    지원    700
# 선우재민   서울   6.0  총무부  여자  4000.0  800    지원    900

# %%
result = payment.drop(['장도윤', '선우재민'], axis='index')
result
# Out:
#     출장지역  출장기간   부서  성별     교통비   식비 차량 지원  최종 식비
# 사원명
# 강미림   서울   3.0  영업부  남자  1000.0  500    지원    600
# 김상민   부산   7.0  전산부  남자  3000.0  600    지원    700
# 신승현   부산   5.0  영업부  여자     NaN  200    지원    300

# %%
result = payment.drop(['출장기간'], axis='columns')
result
# Out:
#      출장지역   부서  성별     교통비   식비 차량 지원  최종 식비
# 사원명
# 강미림    서울  영업부  남자  1000.0  500    지원    600
# 장도윤    서울  총무부  남자  2000.0  300    지원    400
# 김상민    부산  전산부  남자  3000.0  600    지원    700
# 신승현    부산  영업부  여자     NaN  200    지원    300
# 선우재민   서울  총무부  여자  4000.0  800    지원    900

# %%
result = payment.drop(['차량 지원', '부서'], axis='columns')
result
# Out:
#      출장지역  출장기간  성별     교통비   식비  최종 식비
# 사원명
# 강미림    서울   3.0  남자  1000.0  500    600
# 장도윤    서울   NaN  남자  2000.0  300    400
# 김상민    부산   7.0  남자  3000.0  600    700
# 신승현    부산   5.0  여자     NaN  200    300
# 선우재민   서울   6.0  여자  4000.0  800    900

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
chartdata01 = payment['식비']
chartdata01
# Out:
# 사원명
# 강미림     500
# 장도윤     300
# 김상민     600
# 신승현     200
# 선우재민    800
# Name: 식비, dtype: int64

# %%
chartdata01.plot(kind='pie', shadow=True, explode=(0, 0, 0, 0, 0),autopct='%1.1f%%')
plt.xlabel(chartdata01.index.name)
plt.title(f'{chartdata01.name} 지급율')
# Out:
# Text(0.5, 1.0, '식비 지급율')
